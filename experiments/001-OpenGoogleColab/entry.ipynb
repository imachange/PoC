# %% [markdown]
# <a href="https://colab.research.google.com/github/imachange/PoC/blob/main/experiments/001-OpenGoogleColab/entry.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Hello Google Colab!

# %%
print("Hello")
# Out:
# Hello
